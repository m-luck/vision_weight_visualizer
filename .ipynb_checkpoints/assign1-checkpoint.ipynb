# %% [markdown]
# ## Writeup
# #### Includes output of code. Code responsible can be found in cells below.
#
# Using matplotlib and jupyter lab's visualization capabilities, we can display some of the images just to check that they look right. We take samples from our training set and our test set to make sure they look like what we expect them to look like. We expect a good randomized split to have similarly distributed categories, which we indeed see here.
#
# ##### **Samples from Training Loader**
#
# ![train_sample_imgs](img/2019-10-02_21-21.png)
#
# ##### **Samples from Test Loader**
#
# ![test_sample_imgs](img/2019-10-02_21-21_1.png)
#
# Next, let's train a network to accurately categorize these numbers as best they can. An output with the default settings below creates a trace summarized like:
#
# ```
# Train network with default.
#
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.473092
# Train Epoch: 1 [57600/60000 (96%)]	Loss: 0.613135
# Test set: Average loss: 0.3342, Accuracy: 9073/10000 (90%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.432176
# Train Epoch: 2 [57600/60000 (96%)]	Loss: 0.250986
# Test set: Average loss: 0.3064, Accuracy: 9144/10000 (91%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.276413
# Train Epoch: 3 [57600/60000 (96%)]	Loss: 0.200941
# Test set: Average loss: 0.2934, Accuracy: 9163/10000 (91%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.252296
# Train Epoch: 4 [57600/60000 (96%)]	Loss: 0.357095
# Test set: Average loss: 0.2884, Accuracy: 9191/10000 (91%)
#
# Train Epoch: 5 [0/60000 (0%)]	Loss: 0.407383
# Train Epoch: 5 [57600/60000 (96%)]	Loss: 0.218538
# Test set: Average loss: 0.2856, Accuracy: 9212/10000 (92%)
#
# Train Epoch: 6 [0/60000 (0%)]	Loss: 0.285519
# Train Epoch: 6 [57600/60000 (96%)]	Loss: 0.314444
# Test set: Average loss: 0.2810, Accuracy: 9206/10000 (92%)
#
# Train Epoch: 7 [0/60000 (0%)]	Loss: 0.298814
# Train Epoch: 7 [57600/60000 (96%)]	Loss: 0.295985
# Test set: Average loss: 0.2797, Accuracy: 9213/10000 (92%)
#
# Train Epoch: 8 [0/60000 (0%)]	Loss: 0.215273
# Train Epoch: 8 [57600/60000 (96%)]	Loss: 0.119329
# Test set: Average loss: 0.2779, Accuracy: 9219/10000 (92%)
#
# Train Epoch: 9 [0/60000 (0%)]	Loss: 0.234338
# Train Epoch: 9 [57600/60000 (96%)]	Loss: 0.198892
# Test set: Average loss: 0.2797, Accuracy: 9192/10000 (91%)
#
# Train Epoch: 10 [0/60000 (0%)]	Loss: 0.425154
# Train Epoch: 10 [57600/60000 (96%)]	Loss: 0.312325
# Test set: Average loss: 0.2749, Accuracy: 9208/10000 (92%)
# ```
#
# As we can see, within 10 epochs of going through the training samples with batch size 64 and learning rate 0.01, we reach an network accuracy of about 92% (on the MNIST test set we set aside).
#
# We can actually visualize some of the network's weights by plotting them as images where brighter pixels are heavier weights. There are ten output neurons, corresponding to the ten digit categories. We can in some regard see how the network represents each of these categories through the visualization of the weights. Each weight should roughly describe a separate digit visually, because there are no other layers in this specific network.
#
# ![linear_weights](img/weights.png)
#
# Pretty fascinating. Obviously how we train the model affects how it learns these weights. Let's see what type of accuracy we get if we train for the same number of epochs but only with 50 images each epoch instead of the original 60000. 1) It undergoes gradient descent fewer times overall since it is only one batch per epoch 2) The batch size is smaller because 50 images is less than the original batch size of 64. Ability to generalize to the test set will predictably be weaker.
#
# ```
#
# Train Epoch: 1 [50/50 (100%)]	Loss: 2.362520
#
# Test set: Average loss: 2.3323, Accuracy: 1280/10000 (12%)
#
# Train Epoch: 2 [50/50 (100%)]	Loss: 2.291669
#
# Test set: Average loss: 2.2972, Accuracy: 1546/10000 (15%)
#
# Train Epoch: 3 [50/50 (100%)]	Loss: 2.226800
#
# Test set: Average loss: 2.2634, Accuracy: 1801/10000 (18%)
#
# Train Epoch: 4 [50/50 (100%)]	Loss: 2.168083
#
# Test set: Average loss: 2.2308, Accuracy: 2078/10000 (20%)
#
# Train Epoch: 5 [50/50 (100%)]	Loss: 2.114290
#
# Test set: Average loss: 2.1991, Accuracy: 2303/10000 (23%)
#
# Train Epoch: 6 [50/50 (100%)]	Loss: 2.064373
#
# Test set: Average loss: 2.1688, Accuracy: 2516/10000 (25%)
#
# Train Epoch: 7 [50/50 (100%)]	Loss: 2.017894
#
# Test set: Average loss: 2.1401, Accuracy: 2738/10000 (27%)
#
# Train Epoch: 8 [50/50 (100%)]	Loss: 1.974772
#
# Test set: Average loss: 2.1136, Accuracy: 2993/10000 (29%)
#
# Train Epoch: 9 [50/50 (100%)]	Loss: 1.934924
#
# Test set: Average loss: 2.0893, Accuracy: 3245/10000 (32%)
#
# Train Epoch: 10 [50/50 (100%)]	Loss: 1.898108
#
# Test set: Average loss: 2.0670, Accuracy: 3483/10000 (34%)
# ```
#
# Great, well, not great: the understanding of our network's robustness aligns with our realistic expectation, and is much weaker with this smaller training data set. Now let's add a couple more neurons to the network (actually, around one thousand more) and add some non-linearities, and go back to the full 60,000 images. This will truly allow the network to be more of a universal function approximator. Training with this new architecture, the trace looks like this:
#
# ```
# Train network with 1K hidden units, default learning rate. Output for above:
#
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.388682
# Train Epoch: 1 [57600/60000 (96%)]	Loss: 1.349790
# Test set: Average loss: 1.2900, Accuracy: 8988/10000 (89%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 1.290090
# Train Epoch: 2 [57600/60000 (96%)]	Loss: 1.267681
# Test set: Average loss: 1.2592, Accuracy: 9089/10000 (90%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 1.333322
# Train Epoch: 3 [57600/60000 (96%)]	Loss: 1.335851
# Test set: Average loss: 1.2434, Accuracy: 9146/10000 (91%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 1.243881
# Train Epoch: 4 [57600/60000 (96%)]	Loss: 1.198713
# Test set: Average loss: 1.2328, Accuracy: 9187/10000 (91%)
#
# Train Epoch: 5 [0/60000 (0%)]	Loss: 1.259169
# Train Epoch: 5 [57600/60000 (96%)]	Loss: 1.246339
# Test set: Average loss: 1.2249, Accuracy: 9212/10000 (92%)
#
# Train Epoch: 6 [0/60000 (0%)]	Loss: 1.244869
# Train Epoch: 6 [57600/60000 (96%)]	Loss: 1.268675
# Test set: Average loss: 1.2189, Accuracy: 9234/10000 (92%)
#
# Train Epoch: 7 [0/60000 (0%)]	Loss: 1.211978
# Train Epoch: 7 [57600/60000 (96%)]	Loss: 1.167849
# Test set: Average loss: 1.2138, Accuracy: 9257/10000 (92%)
#
# Train Epoch: 8 [0/60000 (0%)]	Loss: 1.243213
# Train Epoch: 8 [57600/60000 (96%)]	Loss: 1.188967
# Test set: Average loss: 1.2083, Accuracy: 9262/10000 (92%)
#
# Train Epoch: 9 [0/60000 (0%)]	Loss: 1.162763
# Train Epoch: 9 [57600/60000 (96%)]	Loss: 1.162644
# Test set: Average loss: 1.2037, Accuracy: 9298/10000 (92%)
#
# Train Epoch: 10 [0/60000 (0%)]	Loss: 1.170782
# Train Epoch: 10 [57600/60000 (96%)]	Loss: 1.211130
# Test set: Average loss: 1.1995, Accuracy: 9325/10000 (93%)
# ```
#
# A bit better than our original. Not significantly, but it may be the case that the MNIST problem is simple enough for multi-dimension linear regression to provide a very good accuracy. We know that adding the neurons and non-linearity at least did not make it worse.
#
# Other parts of the learning architecture can affect the accuracy of the model. Learning rate needs to be small enough to adjust to reach local optima. In high dimensions these can be very granular. Therefore, increasing the learning rate often means that the network cannot reach as good of local optima, and the network may instead roll back and forth between the losses instead of reaching where it needs to be in the middle. It may initially train faster, but at some point the learning rate being high can be detrimental.
#
# Learning rate set to 10, we can witness this oscillation through the training trace:
#
# ```
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.501547
# Train Epoch: 1 [57600/60000 (96%)]	Loss: 25.326010
# Test set: Average loss: 21.7723, Accuracy: 8608/10000 (86%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 13.702995
# Train Epoch: 2 [57600/60000 (96%)]	Loss: 20.224686
# Test set: Average loss: 23.1968, Accuracy: 8493/10000 (84%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 24.169605
# Train Epoch: 3 [57600/60000 (96%)]	Loss: 13.673943
# Test set: Average loss: 16.4016, Accuracy: 8949/10000 (89%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 19.099495
# Train Epoch: 4 [57600/60000 (96%)]	Loss: 5.822874
# Test set: Average loss: 58.1573, Accuracy: 7518/10000 (75%)
#
# Train Epoch: 5 [0/60000 (0%)]	Loss: 92.876732
# Train Epoch: 5 [57600/60000 (96%)]	Loss: 8.907503
# Test set: Average loss: 22.9707, Accuracy: 8603/10000 (86%)
#
# Train Epoch: 6 [0/60000 (0%)]	Loss: 12.534538
# Train Epoch: 6 [57600/60000 (96%)]	Loss: 17.273514
# Test set: Average loss: 17.5142, Accuracy: 8885/10000 (88%)
#
# Train Epoch: 7 [0/60000 (0%)]	Loss: 23.160442
# Train Epoch: 7 [57600/60000 (96%)]	Loss: 12.398312
# Test set: Average loss: 23.4349, Accuracy: 8454/10000 (84%)
#
# Train Epoch: 8 [0/60000 (0%)]	Loss: 15.848520
# Train Epoch: 8 [57600/60000 (96%)]	Loss: 44.016884
# Test set: Average loss: 30.3271, Accuracy: 8140/10000 (81%)
#
# Train Epoch: 9 [0/60000 (0%)]	Loss: 19.532957
# Train Epoch: 9 [57600/60000 (96%)]	Loss: 18.149975
# Test set: Average loss: 17.3688, Accuracy: 8910/10000 (89%)
#
# Train Epoch: 10 [0/60000 (0%)]	Loss: 15.387402
# Train Epoch: 10 [57600/60000 (96%)]	Loss: 6.859781
# Test set: Average loss: 18.0369, Accuracy: 8874/10000 (88%)
# ```
#
# What we mentioned above happens as the model oscillates between higher and lower accuracies. The model is circling in high dimensions around one of the optima.
#
# Another good model to benchmark recognition on is CIFAR10. These images are a bit more structurally complex and diverse, so accuracy is harder to obtain on them. Let's see what it's like to train a model with two convolution layers and two fully connected layers, with some pooling and nonlinearities in between some of them:
#
# ```
# Training on CIFAR, 20 epochs.
#
# Train Epoch: 1 [0/50000 (0%)]	Loss: 2.300737
# Train Epoch: 1 [44800/50000 (90%)]	Loss: 1.872215
# Test set: Average loss: 1.7793, Accuracy: 3792/10000 (37%)
#
# Train Epoch: 2 [0/50000 (0%)]	Loss: 1.910011
# Train Epoch: 2 [44800/50000 (90%)]	Loss: 1.560490
# Test set: Average loss: 1.6069, Accuracy: 4317/10000 (43%)
#
# Train Epoch: 3 [0/50000 (0%)]	Loss: 1.540782
# Train Epoch: 3 [44800/50000 (90%)]	Loss: 1.632895
# Test set: Average loss: 1.4752, Accuracy: 4733/10000 (47%)
#
# Train Epoch: 4 [0/50000 (0%)]	Loss: 1.578840
# Train Epoch: 4 [44800/50000 (90%)]	Loss: 1.420997
# Test set: Average loss: 1.3857, Accuracy: 5023/10000 (50%)
#
# Train Epoch: 5 [0/50000 (0%)]	Loss: 1.332089
# Train Epoch: 5 [44800/50000 (90%)]	Loss: 1.280774
# Test set: Average loss: 1.3633, Accuracy: 5105/10000 (51%)
#
# Train Epoch: 6 [0/50000 (0%)]	Loss: 1.522256
# Train Epoch: 6 [44800/50000 (90%)]	Loss: 1.426836
# Test set: Average loss: 1.2879, Accuracy: 5371/10000 (53%)
#
# Train Epoch: 7 [0/50000 (0%)]	Loss: 1.186929
# Train Epoch: 7 [44800/50000 (90%)]	Loss: 1.113312
# Test set: Average loss: 1.3069, Accuracy: 5335/10000 (53%)
#
# Train Epoch: 8 [0/50000 (0%)]	Loss: 1.155056
# Train Epoch: 8 [44800/50000 (90%)]	Loss: 1.033155
# Test set: Average loss: 1.2702, Accuracy: 5487/10000 (54%)
#
# Train Epoch: 9 [0/50000 (0%)]	Loss: 1.177837
# Train Epoch: 9 [44800/50000 (90%)]	Loss: 0.916196
# Test set: Average loss: 1.1710, Accuracy: 5812/10000 (58%)
#
# Train Epoch: 10 [0/50000 (0%)]	Loss: 1.121376
# Train Epoch: 10 [44800/50000 (90%)]	Loss: 1.070894
# Test set: Average loss: 1.3454, Accuracy: 5155/10000 (51%)
#
# Train Epoch: 11 [0/50000 (0%)]	Loss: 1.636969
# Train Epoch: 11 [44800/50000 (90%)]	Loss: 1.046075
# Test set: Average loss: 1.1152, Accuracy: 6055/10000 (60%)
#
# Train Epoch: 12 [0/50000 (0%)]	Loss: 0.969417
# Train Epoch: 12 [44800/50000 (90%)]	Loss: 0.843105
# Test set: Average loss: 1.0893, Accuracy: 6095/10000 (60%)
#
# Train Epoch: 13 [0/50000 (0%)]	Loss: 0.889332
# Train Epoch: 13 [44800/50000 (90%)]	Loss: 1.145184
# Test set: Average loss: 1.0472, Accuracy: 6294/10000 (62%)
#
# Train Epoch: 14 [0/50000 (0%)]	Loss: 1.000693
# Train Epoch: 14 [44800/50000 (90%)]	Loss: 1.041758
# Test set: Average loss: 1.0262, Accuracy: 6382/10000 (63%)
#
# Train Epoch: 15 [0/50000 (0%)]	Loss: 0.926763
# Train Epoch: 15 [44800/50000 (90%)]	Loss: 0.777777
# Test set: Average loss: 1.0292, Accuracy: 6407/10000 (64%)
#
# Train Epoch: 16 [0/50000 (0%)]	Loss: 0.879866
# Train Epoch: 16 [44800/50000 (90%)]	Loss: 0.924218
# Test set: Average loss: 0.9962, Accuracy: 6510/10000 (65%)
#
# Train Epoch: 17 [0/50000 (0%)]	Loss: 0.845747
# Train Epoch: 17 [44800/50000 (90%)]	Loss: 0.994221
# Test set: Average loss: 1.0402, Accuracy: 6302/10000 (63%)
#
# Train Epoch: 18 [0/50000 (0%)]	Loss: 0.897990
# Train Epoch: 18 [44800/50000 (90%)]	Loss: 0.772307
# Test set: Average loss: 1.0550, Accuracy: 6253/10000 (62%)
#
# Train Epoch: 19 [0/50000 (0%)]	Loss: 0.721610
# Train Epoch: 19 [44800/50000 (90%)]	Loss: 0.801334
# Test set: Average loss: 0.9743, Accuracy: 6528/10000 (65%)
#
# Train Epoch: 20 [0/50000 (0%)]	Loss: 0.769472
# Train Epoch: 20 [44800/50000 (90%)]	Loss: 0.932327
# Test set: Average loss: 0.9982, Accuracy: 6512/10000 (65%)
# ```
#
# Not bad. For a simple shallow model this is a pretty respectable outcome on CIFAR, obviously not the best but a reassuring higher-than-chance accuracy.
#
# We can visualize the first layers here as well, just like we did with MNIST. In this case, the layers are not as meaningful to our human eye, because they are just the first of a series of filters that allow the network to accurately do a forward pass on the data. Mostly, these filters might be edge detectors or other things low-level. The brightness is relative depending on the preprocessing of the weights -- here we've just translated them to some RGB values based on their own sensitivities to RGB values, where brighter is heavier weights. Each of these 5 x 5 boxes is a 5 x 5 convolution filter! The first layer has 16 of these.
#
# ![conv_filters](img/2019-10-03_00-01.png)
#
# Overall, the model has parameters proportional to the amount of weights that it must specify and adjust. We can think of these as including connections between neurons. Calculating this by peeking into the network parameters, we see this particular convolutional neural network has `258058` trainable parameters. Broken down, these are:
#
# 1200 (sixteen filters of size 25 pixels times 3 color channels from first conv layer)
# 16 (weighting the sixteen filters themselves)
# 51200 (128 filters of size 25 pixels times 16 connections to each filter from the previous layer)
# 128 (weighting the 128 filters themselves)
# 204800 (3200 inputs from the previous layer each going to 64 outputs in layerA, fully connected)
# 64 (weighting the 64 outputs themselves)
# 640 (64 inputs going to 10 outputs each, fully connected)
# 10 (weighting the final outputs themselves)
#
# self.conv1 = nn.Conv2d(3, 16, 5)
#         self.conv2 = nn.Conv2d(16, 128, 5)
#         self.layerA = nn.Linear(3200, 64) # Units discovered using flatten()
#         self.layerB = nn.Linear(64, 10)
#
#
# Author of writeup: Michael Lukiman

# %% [markdown]
# # Computer Vision CSCI-GA.2272-001 Assignment 1
#
# ## Introduction
#
# This assignment is an introduction to using PyTorch for training simple neural net models. Two different datasets will be used:
# - MNIST digits [handwritten digits]
# - CIFAR-10 [32x32 resolution color images of 10 object classes].
#
# ## Requirements
#
# You should perform this assignment in PyTorch, modify this ipython notebook
#
# To install PyTorch, follow instructions at http://pytorch.org/
#
# Please submit your assignment by uploading this iPython notebook to NYU classes.
#
# ## Warmup [10%]
#
# It is always good practice to visually inspect your data before trying to train a model, since it lets you check for problems and get a feel for the task at hand.
#
# MNIST is a dataset of 70,000 grayscale hand-written digits (0 through 9).
# 60,000 of these are training images. 10,000 are a held out test set.
#
# CIFAR-10 is a dataset of 60,000 color images (32 by 32 resolution) across 10 classes
# (airplane, automobile, bird, cat, deer, dog, frog, horse, ship, truck).
# The train/test split is 50k/10k.
#
# Use `matplotlib` and ipython notebook's visualization capabilities to display some of these images.
# [See this PyTorch tutorial page](http://pytorch.org/tutorials/beginner/blitz/cifar10_tutorial.html#sphx-glr-beginner-blitz-cifar10-tutorial-py) for hints on how to achieve this.
#
# ** Relevant Cell: "Data Loading" **

# %%
from __future__ import print_function
import argparse
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms, utils
from torch.autograd import Variable

# Additional packages other than default notebook.
from matplotlib import pyplot as plt
import numpy as np
from torchviz import make_dot

# options
dataset = 'mnist' # options: 'mnist' | 'cifar10'
batch_size = 64   # input batch size for training
epochs = 10      # number of epochs to train
lr = 0.01        # learning rate

if dataset == 'mnist':
    data_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.1307,), (0.3081,))
    ])
    trainset = datasets.MNIST(root='.', train=True, download=True, transform=data_transform)
    testset = datasets.MNIST(root='.', train=False, download=True, transform=data_transform)

elif dataset == 'cifar10':
    data_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
    ])
    trainset = datasets.CIFAR10(root='.', train=True, download=True, transform=data_transform)
    testset = datasets.CIFAR10(root='.', train=False, download=True, transform=data_transform)

train_loader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=0)
test_loader  = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=0)

# %%
def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


# get some random training images
dataiter = iter(train_loader)
images, labels = dataiter.next()

# show images
imshow(utils.make_grid(images))

# get some random training images
dataiter = iter(test_loader)
images, labels = dataiter.next()

# show images
imshow(utils.make_grid(images))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Training a Single Layer Network on MNIST [20%]
#
# Start by running the training on MNIST.
# By default if you run this notebook successfully, it will train on MNIST.
#
# This will initialize a single layer model train it on the 50,000 MNIST training images for 10 epochs (passes through the training data).
#
# The loss function [cross_entropy](http://pytorch.org/docs/master/nn.html?highlight=cross_entropy#torch.nn.functional.cross_entropy) computes a Logarithm of the Softmax on the output of the neural network, and then computes the negative log-likelihood w.r.t. the given `target`.
#
# The default values for the learning rate, batch size and number of epochs are given in the "options" cell of this notebook.
# Unless otherwise specified, use the default values throughout this assignment.
#
# Note the decrease in training loss and corresponding decrease in validation errors.
#
# Paste the output into your report.
# (a): Add code to plot out the network weights as images (one for each output, of size 28 by 28) after the last epoch. Grab a screenshot of the figure and include it in your report. (Hint threads: [#1](https://discuss.pytorch.org/t/understanding-deep-network-visualize-weights/2060/2?u=smth) [#2](https://github.com/pytorch/vision#utils) )

# %%
## network and optimizer
if dataset == 'mnist':
    num_inputs = 784
elif dataset == 'cifar10':
    num_inputs = 3072

num_outputs = 10 # same for both CIFAR10 and MNIST, both have 10 classes as outputs

class Net(nn.Module):
    def __init__(self, num_inputs, num_outputs):
        super(Net, self).__init__()
        self.linear = nn.Linear(num_inputs, num_outputs)
    def forward(self, input):
        input = input.view(-1, num_inputs) # reshape input to batch x num_inputs
        output = self.linear(input)
        return output

network = Net(num_inputs, num_outputs)
optimizer = optim.SGD(network.parameters(), lr=lr)

def train(network, epoch):
    network.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = Variable(data), Variable(target)
        optimizer.zero_grad()
        output = network(data)
        loss = F.cross_entropy(output, target)
        loss.backward()
        optimizer.step()
        if batch_idx % 100 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.data.item()))

def test(network, last_epoch=False):
    with torch.no_grad():
        network.eval()
        test_loss = 0
        correct = 0
        for data, target in test_loader:
            data, target = Variable(data, volatile=True), Variable(target)
            output = network(data)
            test_loss += F.cross_entropy(output, target, reduction='sum').data.item() # sum up batch loss
            pred = output.data.max(1, keepdim=True)[1] # get the index of the max log-probability
            correct += pred.eq(target.data.view_as(pred)).cpu().sum()

        test_loss /= len(test_loader.dataset)
        print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
            test_loss, correct, len(test_loader.dataset),
            100. * correct / len(test_loader.dataset)))

# %%
for epoch in range(1, epochs + 1):
    train(epoch)
    test()

# %% [raw]
# Train network with default. Output for above:
#
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.473092
# Train Epoch: 1 [57600/60000 (96%)]	Loss: 0.613135
# Test set: Average loss: 0.3342, Accuracy: 9073/10000 (90%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.432176
# Train Epoch: 2 [57600/60000 (96%)]	Loss: 0.250986
# Test set: Average loss: 0.3064, Accuracy: 9144/10000 (91%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.276413
# Train Epoch: 3 [57600/60000 (96%)]	Loss: 0.200941
# Test set: Average loss: 0.2934, Accuracy: 9163/10000 (91%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.252296
# Train Epoch: 4 [57600/60000 (96%)]	Loss: 0.357095
# Test set: Average loss: 0.2884, Accuracy: 9191/10000 (91%)
#
# Train Epoch: 5 [0/60000 (0%)]	Loss: 0.407383
# Train Epoch: 5 [57600/60000 (96%)]	Loss: 0.218538
# Test set: Average loss: 0.2856, Accuracy: 9212/10000 (92%)
#
# Train Epoch: 6 [0/60000 (0%)]	Loss: 0.285519
# Train Epoch: 6 [57600/60000 (96%)]	Loss: 0.314444
# Test set: Average loss: 0.2810, Accuracy: 9206/10000 (92%)
#
# Train Epoch: 7 [0/60000 (0%)]	Loss: 0.298814
# Train Epoch: 7 [57600/60000 (96%)]	Loss: 0.295985
# Test set: Average loss: 0.2797, Accuracy: 9213/10000 (92%)
#
# Train Epoch: 8 [0/60000 (0%)]	Loss: 0.215273
# Train Epoch: 8 [57600/60000 (96%)]	Loss: 0.119329
# Test set: Average loss: 0.2779, Accuracy: 9219/10000 (92%)
#
# Train Epoch: 9 [0/60000 (0%)]	Loss: 0.234338
# Train Epoch: 9 [57600/60000 (96%)]	Loss: 0.198892
# Test set: Average loss: 0.2797, Accuracy: 9192/10000 (91%)
#
# Train Epoch: 10 [0/60000 (0%)]	Loss: 0.425154
# Train Epoch: 10 [57600/60000 (96%)]	Loss: 0.312325
# Test set: Average loss: 0.2749, Accuracy: 9208/10000 (92%)

# %%
for name, weight in network.state_dict().items():
    print(name, weight)
    if name=='linear.weight':
        num_cols = 5
        num_kernels = weight.shape[0]
        num_rows = 1 + num_kernels // num_cols
        fig = plt.figure(figsize=(num_cols,num_rows))
        for i in range(weight.shape[0]):
            ax1 = fig.add_subplot(num_rows,num_cols,i+1)
            image_pixels = weight.tolist()[i]
            image = np.reshape(image_pixels, (-1, 28))
            ax1.imshow(image)
            ax1.axis('off')
            ax1.set_xticklabels([])
            ax1.set_yticklabels([])
        plt.subplots_adjust(wspace=0.1, hspace=0.1)
        plt.show()
        # Wow!
# Out:
# linear.weight tensor([[ 1.1831e-02,  1.2162e-02,  2.6806e-02,  ..., -2.7807e-02,
#           2.3772e-02, -8.9213e-03],
#         [-7.1571e-03, -1.7046e-02,  1.5605e-02,  ...,  1.9322e-02,
#           8.2628e-03,  9.5532e-03],
#         [-1.6292e-02, -8.2294e-04, -4.5438e-02,  ...,  1.1936e-02,
#          -4.1764e-02, -4.0247e-02],
#         ...,
#         [-3.5425e-02, -8.3602e-05,  1.8134e-02,  ...,  1.5945e-02,
#           3.8415e-03,  2.2798e-02],
#         [-7.5982e-03, -1.9207e-02,  1.3761e-02,  ..., -2.2034e-02,
#           3.5478e-02,  3.3602e-02],
#         [-2.4144e-02,  1.0248e-03, -1.0617e-02,  ...,  3.8033e-02,
#           3.8836e-02,  2.9389e-02]])
# linear.bias tensor([-0.0393,  0.0048,  0.0514,  0.0287, -0.0377,  0.0230,  0.0221, -0.0223,
#         -0.0370, -0.0270])

# %% [markdown]
# (b): Reduce the number of training examples to just 50. [Hint: limit the iterator in the `train` function].
# Paste the output into your report and explain what is happening to the model.

# %%
network = Net(num_inputs, num_outputs)
optimizer = optim.SGD(network.parameters(), lr=lr)
for batch_idx, (data, target) in enumerate(train_loader):
    if batch_idx == 0: 
        limited_samples = (data[:50], target[:50]) # Limit to 50. 
        break
        
def train(network, epoch):
    network.train()
    data, target = limited_samples
    optimizer.zero_grad()
    output = network(data)
    loss = F.cross_entropy(output, target)
    loss.backward()
    optimizer.step()
    print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
        epoch, len(data), len(data),
        100. * len(data) / len(data), loss.data.item()))
            
for epoch in range(1, 10 + 1):
    train(network, epoch)
    test(network)

# %% [raw]
# Single layer MNIST with a training set of only 50 images.
#
# Train Epoch: 1 [50/50 (100%)]	Loss: 2.362520
#
# Test set: Average loss: 2.3323, Accuracy: 1280/10000 (12%)
#
# Train Epoch: 2 [50/50 (100%)]	Loss: 2.291669
#
# Test set: Average loss: 2.2972, Accuracy: 1546/10000 (15%)
#
# Train Epoch: 3 [50/50 (100%)]	Loss: 2.226800
#
# Test set: Average loss: 2.2634, Accuracy: 1801/10000 (18%)
#
# Train Epoch: 4 [50/50 (100%)]	Loss: 2.168083
#
# Test set: Average loss: 2.2308, Accuracy: 2078/10000 (20%)
#
# Train Epoch: 5 [50/50 (100%)]	Loss: 2.114290
#
# Test set: Average loss: 2.1991, Accuracy: 2303/10000 (23%)
#
# Train Epoch: 6 [50/50 (100%)]	Loss: 2.064373
#
# Test set: Average loss: 2.1688, Accuracy: 2516/10000 (25%)
#
# Train Epoch: 7 [50/50 (100%)]	Loss: 2.017894
#
# Test set: Average loss: 2.1401, Accuracy: 2738/10000 (27%)
#
# Train Epoch: 8 [50/50 (100%)]	Loss: 1.974772
#
# Test set: Average loss: 2.1136, Accuracy: 2993/10000 (29%)
#
# Train Epoch: 9 [50/50 (100%)]	Loss: 1.934924
#
# Test set: Average loss: 2.0893, Accuracy: 3245/10000 (32%)
#
# Train Epoch: 10 [50/50 (100%)]	Loss: 1.898108
#
# Test set: Average loss: 2.0670, Accuracy: 3483/10000 (34%)

# %% [markdown]
# ## Training a Multi-Layer Network on MNIST [20%]
#
# - Add an extra layer to the network with 1000 hidden units and a `tanh` non-linearity. [Hint: modify the `Net` class]. Train the model for 10 epochs and save the output into your report.
# -  Now set the learning rate to 10 and observe what happens during training. Save the output in your report and give a brief explanation

# %%
class Net(nn.Module):
    def __init__(self, num_inputs, num_outputs):
        super().__init__()
        
        self.layer1 = nn.Linear(num_inputs, 1000)
        self.layer2 = nn.Linear(1000, num_outputs)
        self.activation = nn.Tanh()
    def forward(self, input):
        input = input.view(-1, num_inputs) # reshape input to batch x num_inputs
        first = self.layer1(input)
        first_activation = self.activation(first)
        second = self.layer2(first_activation)
        second_activation = self.activation(second)
        output = self.activation(second_activation)
        
        return output

network = Net(num_inputs, num_outputs)
optimizer = optim.SGD(network.parameters(), lr=lr)

for epoch in range(1, 10 + 1):
    train(network, epoch)
    test(network)

# %% [raw]
# Train network with 1K hidden units, default learning rate. Output for above:
#
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.388682
# Train Epoch: 1 [57600/60000 (96%)]	Loss: 1.349790
# Test set: Average loss: 1.2900, Accuracy: 8988/10000 (89%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 1.290090
# Train Epoch: 2 [57600/60000 (96%)]	Loss: 1.267681
# Test set: Average loss: 1.2592, Accuracy: 9089/10000 (90%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 1.333322
# Train Epoch: 3 [57600/60000 (96%)]	Loss: 1.335851
# Test set: Average loss: 1.2434, Accuracy: 9146/10000 (91%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 1.243881
# Train Epoch: 4 [57600/60000 (96%)]	Loss: 1.198713
# Test set: Average loss: 1.2328, Accuracy: 9187/10000 (91%)
#
# Train Epoch: 5 [0/60000 (0%)]	Loss: 1.259169
# Train Epoch: 5 [57600/60000 (96%)]	Loss: 1.246339
# Test set: Average loss: 1.2249, Accuracy: 9212/10000 (92%)
#
# Train Epoch: 6 [0/60000 (0%)]	Loss: 1.244869
# Train Epoch: 6 [57600/60000 (96%)]	Loss: 1.268675
# Test set: Average loss: 1.2189, Accuracy: 9234/10000 (92%)
#
# Train Epoch: 7 [0/60000 (0%)]	Loss: 1.211978
# Train Epoch: 7 [57600/60000 (96%)]	Loss: 1.167849
# Test set: Average loss: 1.2138, Accuracy: 9257/10000 (92%)
#
# Train Epoch: 8 [0/60000 (0%)]	Loss: 1.243213
# Train Epoch: 8 [57600/60000 (96%)]	Loss: 1.188967
# Test set: Average loss: 1.2083, Accuracy: 9262/10000 (92%)
#
# Train Epoch: 9 [0/60000 (0%)]	Loss: 1.162763
# Train Epoch: 9 [57600/60000 (96%)]	Loss: 1.162644
# Test set: Average loss: 1.2037, Accuracy: 9298/10000 (92%)
#
# Train Epoch: 10 [0/60000 (0%)]	Loss: 1.170782
# Train Epoch: 10 [57600/60000 (96%)]	Loss: 1.211130
# Test set: Average loss: 1.1995, Accuracy: 9325/10000 (93%)

# %%
lr = 10.0

network = Net(num_inputs, num_outputs)
optimizer = optim.SGD(network.parameters(), lr=lr)

for epoch in range(1, epochs + 1):
    train(network, epoch)
    test(network)

# %% [raw]
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.501547
# Train Epoch: 1 [6400/60000 (11%)]	Loss: 23.467651
# Train Epoch: 1 [12800/60000 (21%)]	Loss: 36.777149
# Train Epoch: 1 [19200/60000 (32%)]	Loss: 31.532867
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 10.218654
# Train Epoch: 1 [32000/60000 (53%)]	Loss: 26.185482
# Train Epoch: 1 [38400/60000 (64%)]	Loss: 14.598824
# Train Epoch: 1 [44800/60000 (75%)]	Loss: 28.637650
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 23.049561
# Train Epoch: 1 [57600/60000 (96%)]	Loss: 25.326010
#
# /usr/lib/python3.7/site-packages/ipykernel_launcher.py:41: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#
#
# Test set: Average loss: 21.7723, Accuracy: 8608/10000 (86%)
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 13.702995
# Train Epoch: 2 [6400/60000 (11%)]	Loss: 22.470772
# Train Epoch: 2 [12800/60000 (21%)]	Loss: 13.664997
# Train Epoch: 2 [19200/60000 (32%)]	Loss: 19.706268
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 9.952486
# Train Epoch: 2 [32000/60000 (53%)]	Loss: 22.413864
# Train Epoch: 2 [38400/60000 (64%)]	Loss: 19.228651
# Train Epoch: 2 [44800/60000 (75%)]	Loss: 13.855835
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 25.599108
# Train Epoch: 2 [57600/60000 (96%)]	Loss: 20.224686
#
# Test set: Average loss: 23.1968, Accuracy: 8493/10000 (84%)
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 24.169605
# Train Epoch: 3 [6400/60000 (11%)]	Loss: 19.344801
# Train Epoch: 3 [12800/60000 (21%)]	Loss: 17.020836
# Train Epoch: 3 [19200/60000 (32%)]	Loss: 27.347731
# Train Epoch: 3 [25600/60000 (43%)]	Loss: 20.899813
# Train Epoch: 3 [32000/60000 (53%)]	Loss: 14.612787
# Train Epoch: 3 [38400/60000 (64%)]	Loss: 16.529579
# Train Epoch: 3 [44800/60000 (75%)]	Loss: 31.136688
# Train Epoch: 3 [51200/60000 (85%)]	Loss: 10.526091
# Train Epoch: 3 [57600/60000 (96%)]	Loss: 13.673943
#
# Test set: Average loss: 16.4016, Accuracy: 8949/10000 (89%)
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 19.099495
# Train Epoch: 4 [6400/60000 (11%)]	Loss: 16.726080
# Train Epoch: 4 [12800/60000 (21%)]	Loss: 28.122086
# Train Epoch: 4 [19200/60000 (32%)]	Loss: 6.310041
# Train Epoch: 4 [25600/60000 (43%)]	Loss: 37.375381
# Train Epoch: 4 [32000/60000 (53%)]	Loss: 13.365326
# Train Epoch: 4 [38400/60000 (64%)]	Loss: 20.244553
# Train Epoch: 4 [44800/60000 (75%)]	Loss: 26.635914
# Train Epoch: 4 [51200/60000 (85%)]	Loss: 19.758928
# Train Epoch: 4 [57600/60000 (96%)]	Loss: 5.822874
#
# Test set: Average loss: 58.1573, Accuracy: 7518/10000 (75%)
#
# Train Epoch: 5 [0/60000 (0%)]	Loss: 92.876732
# Train Epoch: 5 [6400/60000 (11%)]	Loss: 18.969772
# Train Epoch: 5 [12800/60000 (21%)]	Loss: 17.249435
# Train Epoch: 5 [19200/60000 (32%)]	Loss: 13.171071
# Train Epoch: 5 [25600/60000 (43%)]	Loss: 11.317869
# Train Epoch: 5 [32000/60000 (53%)]	Loss: 11.484949
# Train Epoch: 5 [38400/60000 (64%)]	Loss: 13.713512
# Train Epoch: 5 [44800/60000 (75%)]	Loss: 25.841063
# Train Epoch: 5 [51200/60000 (85%)]	Loss: 40.690323
# Train Epoch: 5 [57600/60000 (96%)]	Loss: 8.907503
#
# Test set: Average loss: 22.9707, Accuracy: 8603/10000 (86%)
#
# Train Epoch: 6 [0/60000 (0%)]	Loss: 12.534538
# Train Epoch: 6 [6400/60000 (11%)]	Loss: 24.428040
# Train Epoch: 6 [12800/60000 (21%)]	Loss: 18.093697
# Train Epoch: 6 [19200/60000 (32%)]	Loss: 6.044755
# Train Epoch: 6 [25600/60000 (43%)]	Loss: 15.394304
# Train Epoch: 6 [32000/60000 (53%)]	Loss: 7.182805
# Train Epoch: 6 [38400/60000 (64%)]	Loss: 21.244854
# Train Epoch: 6 [44800/60000 (75%)]	Loss: 10.658684
# Train Epoch: 6 [51200/60000 (85%)]	Loss: 5.844358
# Train Epoch: 6 [57600/60000 (96%)]	Loss: 17.273514
#
# Test set: Average loss: 17.5142, Accuracy: 8885/10000 (88%)
#
# Train Epoch: 7 [0/60000 (0%)]	Loss: 23.160442
# Train Epoch: 7 [6400/60000 (11%)]	Loss: 12.060244
# Train Epoch: 7 [12800/60000 (21%)]	Loss: 4.028065
# Train Epoch: 7 [19200/60000 (32%)]	Loss: 22.732214
# Train Epoch: 7 [25600/60000 (43%)]	Loss: 12.830122
# Train Epoch: 7 [32000/60000 (53%)]	Loss: 18.211670
# Train Epoch: 7 [38400/60000 (64%)]	Loss: 17.916420
# Train Epoch: 7 [44800/60000 (75%)]	Loss: 26.764465
# Train Epoch: 7 [51200/60000 (85%)]	Loss: 10.720640
# Train Epoch: 7 [57600/60000 (96%)]	Loss: 12.398312
#
# Test set: Average loss: 23.4349, Accuracy: 8454/10000 (84%)
#
# Train Epoch: 8 [0/60000 (0%)]	Loss: 15.848520
# Train Epoch: 8 [6400/60000 (11%)]	Loss: 14.802980
# Train Epoch: 8 [12800/60000 (21%)]	Loss: 8.937613
# Train Epoch: 8 [19200/60000 (32%)]	Loss: 6.417161
# Train Epoch: 8 [25600/60000 (43%)]	Loss: 17.718264
# Train Epoch: 8 [32000/60000 (53%)]	Loss: 27.373335
# Train Epoch: 8 [38400/60000 (64%)]	Loss: 27.887959
# Train Epoch: 8 [44800/60000 (75%)]	Loss: 4.034972
# Train Epoch: 8 [51200/60000 (85%)]	Loss: 13.629025
# Train Epoch: 8 [57600/60000 (96%)]	Loss: 44.016884
#
# Test set: Average loss: 30.3271, Accuracy: 8140/10000 (81%)
#
# Train Epoch: 9 [0/60000 (0%)]	Loss: 19.532957
# Train Epoch: 9 [6400/60000 (11%)]	Loss: 4.677568
# Train Epoch: 9 [12800/60000 (21%)]	Loss: 9.465985
# Train Epoch: 9 [19200/60000 (32%)]	Loss: 20.296162
# Train Epoch: 9 [25600/60000 (43%)]	Loss: 13.749250
# Train Epoch: 9 [32000/60000 (53%)]	Loss: 29.247284
# Train Epoch: 9 [38400/60000 (64%)]	Loss: 8.723548
# Train Epoch: 9 [44800/60000 (75%)]	Loss: 21.609581
# Train Epoch: 9 [51200/60000 (85%)]	Loss: 3.751030
# Train Epoch: 9 [57600/60000 (96%)]	Loss: 18.149975
#
# Test set: Average loss: 17.3688, Accuracy: 8910/10000 (89%)
#
# Train Epoch: 10 [0/60000 (0%)]	Loss: 15.387402
# Train Epoch: 10 [6400/60000 (11%)]	Loss: 18.685478
# Train Epoch: 10 [12800/60000 (21%)]	Loss: 34.670742
# Train Epoch: 10 [19200/60000 (32%)]	Loss: 16.469706
# Train Epoch: 10 [25600/60000 (43%)]	Loss: 38.659409
# Train Epoch: 10 [32000/60000 (53%)]	Loss: 17.472614
# Train Epoch: 10 [38400/60000 (64%)]	Loss: 9.422314
# Train Epoch: 10 [44800/60000 (75%)]	Loss: 39.450001
# Train Epoch: 10 [51200/60000 (85%)]	Loss: 11.700812
# Train Epoch: 10 [57600/60000 (96%)]	Loss: 6.859781
#
# Test set: Average loss: 18.0369, Accuracy: 8874/10000 (88%)

# %% [markdown]
# ## Training a Convolutional Network on CIFAR [50%]
#
# To change over to the CIFAR-10 dataset, change the `options` cell's `dataset` variable to `'cifar10'`.
#
# - Create a convolutional network with the following architecture:
#   - Convolution with 5 by 5 filters, 16 feature maps + Tanh nonlinearity.
#   - 2 by 2 max pooling.
#   - Convolution with 5 by 5 filters, 128 feature maps + Tanh nonlinearity.
#   - 2 by 2 max pooling.
#   - Flatten to vector.
#   - Linear layer with 64 hidden units + Tanh nonlinearity.
#   - Linear layer to 10 output units.
#
# Train it for 20 epochs on the CIFAR-10 training set and copy the output
# into your report, along with a image of the first layer filters.
#
# Hints: [Follow the first PyTorch tutorial](http://pytorch.org/tutorials/beginner/blitz/neural_networks_tutorial.html#sphx-glr-beginner-blitz-neural-networks-tutorial-py) or look at the [MNIST example](https://github.com/pytorch/examples/tree/master/mnist)
#
# - Give a breakdown of the parameters within the above model, and the overall number.

# %%
import torch.nn.functional as F

# options
dataset = 'cifar10' # options: 'mnist' | 'cifar10'
lr = 0.01        # learning rate

if dataset == 'mnist':
    data_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.1307,), (0.3081,))
    ])
    trainset = datasets.MNIST(root='.', train=True, download=True, transform=data_transform)
    testset = datasets.MNIST(root='.', train=False, download=True, transform=data_transform)

elif dataset == 'cifar10':
    data_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
    ])
    trainset = datasets.CIFAR10(root='.', train=True, download=True, transform=data_transform)
    testset = datasets.CIFAR10(root='.', train=False, download=True, transform=data_transform)

train_loader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=0)
test_loader  = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=0)

class CNN(torch.nn.Module):
    
    
    def __init__(self):
        super(CNN, self).__init__()
        # 1 input image channel, 6 output channels, 3x3 square convolution
        # kernel
        self.conv1 = nn.Conv2d(3, 16, 5)
        self.conv2 = nn.Conv2d(16, 128, 5)
        self.layerA = nn.Linear(3200, 64) # Units discovered using flatten()
        self.layerB = nn.Linear(64, 10)

    def forward(self, x):
        # Max pooling over a (2, 2) window
        x = F.max_pool2d(F.tanh(self.conv1(x)), 2)
        x = F.max_pool2d(F.tanh(self.conv2(x)), 2)
        x = x.view(-1, self.num_flat_features(x))
        x = F.tanh(self.layerA(x))
        x = self.layerB(x)
        return x

    def num_flat_features(self, x):
        size = x.size()[1:]  # all dimensions except the batch dimension
        num_features = 1
        for s in size:
            num_features *= s
        return num_features

net = CNN()
lr = 0.01
optimizer = optim.SGD(net.parameters(), lr=lr)
epochs = 20

for epoch in range(1, epochs + 1):
    train(net, epoch)
    test(net)

# %% [raw]
# Training on CIFAR, 20 epochs.
#
# Train Epoch: 1 [0/50000 (0%)]	Loss: 2.300737
# Train Epoch: 1 [44800/50000 (90%)]	Loss: 1.872215
# Test set: Average loss: 1.7793, Accuracy: 3792/10000 (37%)
#
# Train Epoch: 2 [0/50000 (0%)]	Loss: 1.910011
# Train Epoch: 2 [44800/50000 (90%)]	Loss: 1.560490
# Test set: Average loss: 1.6069, Accuracy: 4317/10000 (43%)
#
# Train Epoch: 3 [0/50000 (0%)]	Loss: 1.540782
# Train Epoch: 3 [44800/50000 (90%)]	Loss: 1.632895
# Test set: Average loss: 1.4752, Accuracy: 4733/10000 (47%)
#
# Train Epoch: 4 [0/50000 (0%)]	Loss: 1.578840
# Train Epoch: 4 [44800/50000 (90%)]	Loss: 1.420997
# Test set: Average loss: 1.3857, Accuracy: 5023/10000 (50%)
#
# Train Epoch: 5 [0/50000 (0%)]	Loss: 1.332089
# Train Epoch: 5 [44800/50000 (90%)]	Loss: 1.280774
# Test set: Average loss: 1.3633, Accuracy: 5105/10000 (51%)
#
# Train Epoch: 6 [0/50000 (0%)]	Loss: 1.522256
# Train Epoch: 6 [44800/50000 (90%)]	Loss: 1.426836
# Test set: Average loss: 1.2879, Accuracy: 5371/10000 (53%)
#
# Train Epoch: 7 [0/50000 (0%)]	Loss: 1.186929
# Train Epoch: 7 [44800/50000 (90%)]	Loss: 1.113312
# Test set: Average loss: 1.3069, Accuracy: 5335/10000 (53%)
#
# Train Epoch: 8 [0/50000 (0%)]	Loss: 1.155056
# Train Epoch: 8 [44800/50000 (90%)]	Loss: 1.033155
# Test set: Average loss: 1.2702, Accuracy: 5487/10000 (54%)
#
# Train Epoch: 9 [0/50000 (0%)]	Loss: 1.177837
# Train Epoch: 9 [44800/50000 (90%)]	Loss: 0.916196
# Test set: Average loss: 1.1710, Accuracy: 5812/10000 (58%)
#
# Train Epoch: 10 [0/50000 (0%)]	Loss: 1.121376
# Train Epoch: 10 [44800/50000 (90%)]	Loss: 1.070894
# Test set: Average loss: 1.3454, Accuracy: 5155/10000 (51%)
#
# Train Epoch: 11 [0/50000 (0%)]	Loss: 1.636969
# Train Epoch: 11 [44800/50000 (90%)]	Loss: 1.046075
# Test set: Average loss: 1.1152, Accuracy: 6055/10000 (60%)
#
# Train Epoch: 12 [0/50000 (0%)]	Loss: 0.969417
# Train Epoch: 12 [44800/50000 (90%)]	Loss: 0.843105
# Test set: Average loss: 1.0893, Accuracy: 6095/10000 (60%)
#
# Train Epoch: 13 [0/50000 (0%)]	Loss: 0.889332
# Train Epoch: 13 [44800/50000 (90%)]	Loss: 1.145184
# Test set: Average loss: 1.0472, Accuracy: 6294/10000 (62%)
#
# Train Epoch: 14 [0/50000 (0%)]	Loss: 1.000693
# Train Epoch: 14 [44800/50000 (90%)]	Loss: 1.041758
# Test set: Average loss: 1.0262, Accuracy: 6382/10000 (63%)
#
# Train Epoch: 15 [0/50000 (0%)]	Loss: 0.926763
# Train Epoch: 15 [44800/50000 (90%)]	Loss: 0.777777
# Test set: Average loss: 1.0292, Accuracy: 6407/10000 (64%)
#
# Train Epoch: 16 [0/50000 (0%)]	Loss: 0.879866
# Train Epoch: 16 [44800/50000 (90%)]	Loss: 0.924218
# Test set: Average loss: 0.9962, Accuracy: 6510/10000 (65%)
#
# Train Epoch: 17 [0/50000 (0%)]	Loss: 0.845747
# Train Epoch: 17 [44800/50000 (90%)]	Loss: 0.994221
# Test set: Average loss: 1.0402, Accuracy: 6302/10000 (63%)
#
# Train Epoch: 18 [0/50000 (0%)]	Loss: 0.897990
# Train Epoch: 18 [44800/50000 (90%)]	Loss: 0.772307
# Test set: Average loss: 1.0550, Accuracy: 6253/10000 (62%)
#
# Train Epoch: 19 [0/50000 (0%)]	Loss: 0.721610
# Train Epoch: 19 [44800/50000 (90%)]	Loss: 0.801334
# Test set: Average loss: 0.9743, Accuracy: 6528/10000 (65%)
#
# Train Epoch: 20 [0/50000 (0%)]	Loss: 0.769472
# Train Epoch: 20 [44800/50000 (90%)]	Loss: 0.932327
# Test set: Average loss: 0.9982, Accuracy: 6512/10000 (65%)

# %%
from PIL import Image

for name, layer in net.state_dict().items():
    if name=='conv1.weight':
        imshow(utils.make_grid(layer))
#         filter_grid = []
#         for ind, filter in enumerate(list(layer)):
#             print(f"filter {ind}")
#             pixel_line_r = []
#             pixel_line_g = []
#             pixel_line_b = []
#             for color, channel in enumerate(filter):
#                 for row in list(channel):
#                     for pixel in row:
#                         if color == 0:
#                             pixel_line_r.append(float(pixel)*128+128)
#                         if color == 1:
#                             pixel_line_g.append(float(pixel)*128+128)
#                         if color == 2:
#                             pixel_line_b.append(float(pixel)*128+128)
#             pixel_line = list(zip(pixel_line_r, pixel_line_g, pixel_line_b))
#             print(pixel_line)
#             im = Image.new('RGB', (5,5))
#             im.putdata(pixel_line)
#             filter_grid.append(im)
#         for filter in filter_grid:

# %%
pytorch_total_params = sum(p.numel() for p in net.parameters())
print('General:',pytorch_total_params)
pytorch_total_params = sum(p.numel() for p in net.parameters() if p.requires_grad)
print('Trainable:',pytorch_total_params)

for p in net.parameters():
    if p.requires_grad:
        print(p.numel())
# Out:
# General: 258058
# Trainable: 258058
# 1200
# 16
# 51200
# 128
# 204800
# 64
# 640
# 10
